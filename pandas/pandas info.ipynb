# %% [markdown]
# # ***SERIES STRUCTURE IN PANDAS***

# %% [markdown]
# # its a one dimentional data  which is looking like a soingle spred sheet column having index level #

# %%
import pandas as pd

# %%
S=pd.Series([1,2,3,4,5],)
S
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %% [markdown]
#  # **Labels**
#
# If nothing else is specified, the values are labeled with their index number. First value has index 0, second value has index 1 etc.
#
# This label can be used to access a specified value.

# %%
s=pd.Series([20,3,3,3,4,4])
s[2] # it will give the value of index 2
s[2:] # it will give the value of index 2 to 4
# Out:
# 2    3
# 3    3
# 4    4
# 5    4
# dtype: int64

# %% [markdown]
# # **INDEX:**
#
#  To select only some of the items in the dictionary, use the index argument and specify only the items you want to include in the Series.

# %%
s=pd.Series([1,2,3,4,5],index=["rio","mani","vijay","sachin","dhoni"])
s
# Out:
# rio       1
# mani      2
# vijay     3
# sachin    4
# dhoni     5
# dtype: int64

# %% [markdown]
# # **METHOD -2---USING THE NUMPY**
#
# creating the series :

# %%
import numpy as np
s= np.array([12,34,5,6,77])
rio= pd.Series(s,index=["a","b","c","d","e"])
rio
# Out:
# a    12
# b    34
# c     5
# d     6
# e    77
# dtype: int32

# %% [markdown]
# # **METHOD--3= -----DICTIONARY METHOD**
# creating the series
# Create a simple Pandas Series from a dictionary:

# %%
data ={'name':"rio",'age':20,'city':"chennai"}
series=pd.Series(data,name="student info")
series
# Out:
# name        rio
# age          20
# city    chennai
# Name: student info, dtype: object

# %% [markdown]
# # **SCALER METHOD ----- 4TH METHOD**
#
# used to create single values assigning all index its not uses

# %%
s=pd.Series("good",index=[1,2,3,4,5])
s # it will give the value of index 1 to 5
# Out:
# 1    good
# 2    good
# 3    good
# 4    good
# 5    good
# dtype: object

# %% [markdown]
# # **atributes in series**

# %% [markdown]
# ## Quick Reference Table
#
# | Attribute           | Returns          | Example Use          |
# | ------------------- | ---------------- | -------------------- |
# | `.index`          | Index labels     | `s.index`          |
# | `.values`         | NumPy array      | `s.values`         |
# | `.dtype`          | Data type        | `s.dtype`          |
# | `.name`           | Series name      | `s.name`           |
# | `.shape`          | Dimensions tuple | `s.shape`          |
# | `.size`           | Element count    | `s.size`           |
# | `.ndim`           | Number of dims   | `s.ndim`           |
# | `.empty`          | Is it empty?     | `s.empty`          |
# | `.memory_usage()` | RAM bytes        | `s.memory_usage()` |
# | `.array`          | Underlying array | `s.array`          |
# | `.attrs`          | Metadata dict    | `s.attrs`          |
# | `.index.name`     | Index name       | `s.index.name`     |

# %%
s=pd.Series([1,4,5,6,7,8],index=["rio","raj","babu","nrgyg","mani","vijay"])
print("Size of the series:", s.size) # it will give the size of the series
print("Data type of the series:", s.dtype) # it will give the data type of the series
print("Number of dimensions:", s.ndim) # it will give the number of dimensions of the series
print("Memory usage of the series:", s.memory_usage()) # it will give the memory usage of the series
print(" etch  the only values ",s.values)# 
print("s.index return the  index only:",s.index)
print(s.name)
print(s.shape)
print(s.empty)
print(s.array)#
print()
# Out:
# Size of the series: 6
# Data type of the series: int64
# Number of dimensions: 1
# Memory usage of the series: 96
#  etch  the only values  [1 4 5 6 7 8]
# s.index return the  index only: Index(['rio', 'raj', 'babu', 'nrgyg', 'mani', 'vijay'], dtype='object')
# None
# (6,)
# False
# <NumpyExtensionArray>
# [1, 4, 5, 6, 7, 8]
# Length: 6, dtype: int64

# %% [markdown]
# # ***DATAFRAME STRUCTURE***

# %% [markdown]
# DataFrame¶
# A DataFrame is a table. It contains an array of individual entries, each of which has a certain value. Each entry corresponds to a row (or record) and a column.

# %%
rio={"Name":["rio","ram"],"Age":[20,25],
      "City":["Chennai","Bangalore"] }
s=pd.DataFrame(rio,index=["student1","student2"])
s
# Out:
#          Name  Age       City
# student1  rio   20    Chennai
# student2  ram   25  Bangalore

# %%
ingredients = pd.Series(["4 cups","1 cup","2 large","1 can"],index=["Flour","Millk","Eggs","Spam"],name="Dinner")

# Check your answer

ingredients
# Out:
# Flour     4 cups
# Millk      1 cup
# Eggs     2 large
# Spam       1 can
# Name: Dinner, dtype: object
